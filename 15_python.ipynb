# %% [markdown]
# ## String
# defintion:<br>
#     A sequence of characters. <br>
#     Immutable.<br>
#     string = "Hello World"<br>
#     string[0] = 'H' # This will throw error as strings are immutable.<br>
#     string = a + " " + "World"<br>
#     print(string)<br>
#     # Indexing<br>
#     print(string[0]) # H<br>
#     print(string[1:5]) # Ello<br>
#     print(string[-1]) # d<br>
#     print(string[-5:]) # World<br>
#     print(string[::-1]) # dlroW olleH<br>
#     print(string.capitalize()) # Hello world<br>
#     print(string.upper()) # HELLO WORLD<br>
#     print(string.lower()) # hello world<br>
#     print(string.count('l')) # 3<br>
#     print(string.find('l')) # 2<br>
#     print(string.replace('l', 'L')) # Hello WOrld<br>
#     print(string.strip()) # Hello World<br>

# %%
a = "Aziz Hi"
del a

# %%
# print(a)

# %% [markdown]
# ### Operations on Strings
#
# 1. Arithmetic Operations
# 2. Relational Operations
# 3. Logical Operations
# 4. Membership Operations

# %%
# Arithmetic operations

"Hello" + " " +"World" # is cancotnetion
# Out:
# 'Hello World'

# %%
print("*"*50)
# Out:
# **************************************************

# %%
print("Hello"*4)
# Out:
# HelloHelloHelloHello

# %%
# Relational Operatore
"Hello"!="World"
# Out:
# True

# %%
"Pakistan" > "india"
# Lexiographically
# Out:
# False

# %%
"Goa" < "Kolkata"
# Out:
# True

# %%
"kol" <'Kol'
# Out:
# False

# %%
# Logical operation
"Hello" and "world"
# Out:
# 'world'

# %%
# are you now
# "" -> False
# "wegter" -> True

# %%
"" or "World"
# Out:
# 'World'

# %%
"Hello" or "World"
# Out:
# 'Hello'

# %%
"hello" and "world"
# Out:
# 'world'

# %%
not "Hello"
# Out:
# False

# %%
not ""
# Out:
# True

# %%
# loop operation
c = "Hello world"
for i in c:
    print(i)
print("\n")
for i in c[1:5]: # is mean slicing in c
    print(i)

print('\n')
for i in c[1:11:2]: # is mean 1 is strat , 11 is end , 2 is stepwise
    print(i)
    
print('\n')
for i in c[::-1]:# is reversed print()
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# w
# o
# r
# l
# d
#
#
# e
# l
# l
# o
#
#
# e
# l
#
# o
# l
#
#
# d
# l
# r
# o
# w
#
# o
# l
# l
# e
# H

# %%
# member ship operatore
c
# Out:
# 'Hello world'

# %%
'h' in c
# Out:
# False

# %%
'H' in c
# Out:
# True

# %%
'world' not in c
# Out:
# False

# %% [markdown]
# ### Common Funcation
# 1. len
# 2. max
# 3. min
# 4. sorted

# %%
c = 'Pakistan'
len(c)
# Out:
# 8

# %%
max(c)
# Out:
# 't'

# %%
min(c)
# Out:
# 'P'

# %%
sorted(c)
# Out:
# ['P', 'a', 'a', 'i', 'k', 'n', 's', 't']

# %% [markdown]
# ### Capitaize/Title/Upper/Lower/Swapcase

# %%
"aziz is the Main".capitalize()
# Out:
# 'Aziz is the main'

# %%
"aziz is the main".title()
# Out:
# 'Aziz Is The Main'

# %%
"aziz is the main".upper()
# Out:
# 'AZIZ IS THE MAIN'

# %%
"aziz is the main".lower()
# Out:
# 'aziz is the main'

# %%
c.swapcase()
# Out:
# 'pAKISTAN'

# %% [markdown]
# ### Count

# %%
"it is raning".count("s")
# Out:
# 1

# %% [markdown]
# ### Find/Index

# %%
"it is raning".find("x")
# Out:
# -1

# %%
# "it is raining".index("x")

# %% [markdown]
# ### endswith/stratswith

# %%
"it is raining".endswith("ining")
# Out:
# True

# %%
"it is raining".startswith("it")
# Out:
# True

# %% [markdown]
# ### Format

# %%
"hello my name is {} and i am {}".format("Abdulaziz",30)
# Out:
# 'hello my name is Abdulaziz and i am 30'

# %%
"hello my name is {0} and i am {1}".format("Abdulaziz",30)
# Out:
# 'hello my name is Abdulaziz and i am 30'

# %%
"hello my name is {name} and i am {age}".format(name="Abdulaziz",age=30)
# Out:
# 'hello my name is Abdulaziz and i am 30'

# %%
"Hello my name is {name} and I am {weight}".format(name="Abdul Aziz",age='30',weight=68)
# Out:
# 'Hello my name is Abdul Aziz and I am 68'

# %% [markdown]
# ### 6. isalnum/isalpha/isdecmial/isdigit/isdentifier

# %%
print("FLAT20".isalnum())
print("FLAT20&".isalnum())
# Out:
# True
# False

# %%
print("FlAT".isalpha())
print("FLAT20".isalpha())
# Out:
# True
# False

# %%
print("Hello_world".isidentifier())
print("Hello world".isidentifier())
# Out:
# True
# False

# %%
# print("Hello".is)

# %% [markdown]
# ### 7.Split

# %%
"Who is the pm is pakistan".split()
# Out:
# ['Who', 'is', 'the', 'pm', 'is', 'pakistan']

# %%
"who is the pm of pakistan".split("is")
# Out:
# ['who ', ' the pm of pak', 'tan']

# %% [markdown]
# ### 8.Join

# %%
" ".join(['Who', 'is', 'the', 'pm', 'is', 'pakistan'])
# Out:
# 'Who is the pm is pakistan'

# %%
"-".join(['Who', 'is', 'the', 'pm', 'is', 'pakistan'])
# Out:
# 'Who-is-the-pm-is-pakistan'

# %% [markdown]
# ### 9.Replace

# %%
"Hi my name is Aziz".replace("Aziz","AZIZ")
# Out:
# 'Hi my name is AZIZ'

# %% [markdown]
# ### Strip

# %%
name = "                    Aziz               "
name.strip()
# Out:
# 'Aziz'

# %%
help("string")
# Out:
# Help on module string:
#
# NAME
#     string - A collection of string constants.
#
# MODULE REFERENCE
#     https://docs.python.org/3.11/library/string.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Public module variables:
#
#     whitespace -- a string containing all ASCII whitespace
#     ascii_lowercase -- a string containing all ASCII lowercase letters
#     ascii_uppercase -- a string containing all ASCII uppercase letters
#     ascii_letters -- a string containing all ASCII letters
#     digits -- a string containing all ASCII decimal digits
#     hexdigits -- a string containing all ASCII hexadecimal digits
#     octdigits -- a string containing all ASCII octal digits
# ...
