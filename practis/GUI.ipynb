# %% [markdown]
# # Create the GUI

# %%
from tkinter import *
from PIL import Image,ImageTk
from tkinter import messagebox

# %%
try:
    root = Tk()

    root.title("LOGINE GEMAI")
    root.iconbitmap('C:/Users/Hp/project file/Python/gmail.ico')

    root.geometry("350x500")
    c = Canvas(root,bg='gray16',height=200,width=200)
    filename = PhotoImage(file='artificial-intelligence-icon-png-14771.png')
    background_laable = Label(root,image=filename)
    background_laable.place(x=0,y=0,relheight=1,relwidth=1)

    c.pack()
    root.mainloop()
except:
    print("not apppload iamge")
