# %% [markdown]
# # OOP
# defintion:
# - Classes are blueprints for creating objects. Objects have properties and methods.
# - Inheritance allows one class to inherit properties and methods from another class.
# - Encapsulation is the bundling of data and methods into a single unit.
# - Abstraction is the hiding of implementation details and showing only essential features.
# - Polymorphism is the ability of an object to take on many forms.
# - Objects interact with each other through methods.
#
# 1. In Python is every thing object

# %%
L = [1,2,3,4] # is a variable list
# L.upper() # is not working because is ArttibuteError
c = "pakistan"
print(c.upper())

# %%
a = 2 # this is a class object
print(type(a))

# %%
print(type(L))
L.append(5)

# %% [markdown]
# ## Create the Atm

# %%
class ATM():
    
    # Constructor
    # special/magic/dunder method
    
    # static/class
    __counter = 1
    
    def __init__(self):
        # instance variable is self
        self.__pin = "" # duble underscore means is privet
        self.__balance = 0
        self.sno = ATM.__counter
        ATM.__counter = ATM.__counter + 1
        
        print(id(self))
        
        self.menu()
    @staticmethod
    def get_counter():
        return ATM.__counter
    @staticmethod
    def set_counter(new):
        if type(new) == int:
            ATM.__counter = new
        else:
            print("Not allowed")
            
    def get_pin(self):
        return self.__pin
    
    def set_pin(self,new_pin): 
        if type(new_pin) == str:
            self.__pin = new_pin
            print("Pin change")
        else:
            print("Not allowed")
        
    def menu(self):
        user_input = input("""
                           
                           Hello,how would you llike to proceed?
                           1. Enter 1 to create pin
                           2. Enter 2 to deposit
                           3. Enter 3 to withdraw
                           4. Enter 4 to check balance
                           5. Enter 5 to exit
                           
                           """)
        if user_input == "1":
            self.create_pin()
        elif user_input =='2':
            self.deposit()
        elif user_input == '3':
            self.withdraw()
        elif user_input == '4':
            self.check_balnce()
        else:
            print('bey')
            
        
    def create_pin(self):
        self.__pin = input("Enter the pin")
        print("Pin successfully")
        self.menu()
            
    def deposit(self):
        temp = input("Enter your pin")
            
        if temp == self.__pin:
            amount = int(input("Enter the amount"))
            self.__balance = self.__balance + amount
            print(self.__balance)
            print("Deposit successful")
            self.menu()
        else:
            print("invaild pin")
    def withdraw(self):
            
        temp = input('Enter you pin')
            
        if temp == self.__pin:
            amount = int(input("Enter the amount"))
            if amount < self.__balance:
                self.__balance = self.__balance - amount
                print("Operation successful")
                self.menu()
            else:
                print("Invaild pin")
                self.menu()

    def check_balnce(self):
            
        temp = input("Enter the pin")
            
        if temp == self.__pin:
            print("Your balance is ",self.__balance)

# %%
sup = ATM()
sup.__balance="erkjnvweojbn"
sup.__ATM__balance= "sdmdkffne"
sup.set_pin("5.6")
# Out:
# 2716716078224
# Pin successfully
# invaild pin
# Pin change

# %%
C1 = ATM()
C2 = ATM()

# %%
C3  = ATM()
print(C1.sno)
print(C2.sno)
print(C3.sno)
C1.counter

# %%
ATM.get_counter()

# %%
ATM.set_counter(5)
ATM.get_counter()

# %% [markdown]
# ### Fraction class

# %%
class Fraction:
    
    def __init__(self,n,d): # __init__ is magic datatype
        
        self.num = n
        self.den = d
    
    def __str__(self):
        return "{}/{}".format(self.num,self.den)
    
    def __add__(self,other):
        temp_num = self.num * other.den + other.num * self.den
        temp_den = self.den * other.den
        
        return "{}/{}".format(temp_num,temp_den)
    
    def __sub__(self,other):
        
        temp_num = self.num * other.den - other.num * self.den
        temp_den = self.den * other.den
        
        return "{}/{}".format(temp_num,temp_den)
    
    def __mul__(self,other):
        
        temp_num = self.num * other.num
        temp_den = self.den * other.den
        
        return "{}/{}".format(temp_num,temp_den)
    
    def __truediv__(self,other):
        
        temp_num = self.num * other.den
        temp_den = self.den * other.den
        
        return "{}/{}".format(temp_num,temp_den)

# %%
X = Fraction(12,32)
y = Fraction(5,6)
print(X + y)
print(X - y)
print(X * y)
print(X / y)

# %%
class Customer:
    
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender

def greet(customer):
    if customer.gender == 'Male':
        print("Hello",customer.name,'sir')
    else:
        print("Hello",customer.name,'ma"am')
        
    cust2 = Customer("Nitsh",'Male')
    
    return cust2
    
cust = Customer("Nitsh",'Male')

new_cust = greet(cust)
print(new_cust.name)

# %%
def change(L):
    
    print(id(L))
    L.append(5)
    print(id(L))
    
L1 = [1,2,3,4]
print(id(L1))
print(L1)

change(L1[:])

print(L1)

# %%
def change(L):
    print(id(L))
    L = L +(5,6)
    print(id(L))

L1 = (1,2,3)
print(id(L1))
print(L1)

change(L1)

print(L1)

# %%
class Customer():
    
    def  __init__(self,name,age):
        self.name = name
        self.age = age
        
    def intro(self):
        print("I am",self.name,"and I am",self.age)
        
C1 = Customer("Nitish",34)
C2 = Customer("Nsstish",34)
C3 = Customer("Nffdtish",34)


L = [C1,C2,C3]

for i in L:
    i.intro()

# %% [markdown]
# ## Aggregation

# %%
class Customer:
    
    def __init__(self,name,gender,address):
        
        self.name = name
        self.gender = gender
        self.address = address
        
    def edit_pofile(self,new_name,new_city,new_pin,new_state):
        
        self.name = new_name
        self.address.change_address(new_city,new_pin,new_state)
        
class Addres:
    
    def  __init__(self,city,pincode,state):
        
        self.city = city
        self.pincode = pincode
        self.state = state
        
    def change_address(self,new_city,new_pin,new_state):
    
        self.city = new_city
        self.pincode = new_pin
        self.state = new_state

    
add = Addres("kohat",'123',"pakistan")
cist = Customer("Aziz","male",add)

print(cist.address.city)
print(cist.address.state)

cist.edit_pofile('Ankit','Gurgann',122011,"haryna")

print(cist.address.pincode)

# %% [markdown]
# ### inheritence

# %%
class User():
    
    def login(self):
        print("login")
    def register(self):
        print("Register")

class Student(User):
    
    def enroll(self):
        print("Enroll")
        
    def review(self):
        print("Review")
stu1 = Student()

stu1.enroll()
stu1.review()
stu1.login()
stu1.register()

# %%
u = User()

u.enroll()
u.review()
u.login()
u.register()

# %% [markdown]
# ### Inheriting Constructor

# %%
class Phone:
    
    def __init__(self,price,brand,camera):
        print("inside phone constructoe")
        
        self.price = price
        self.brand = brand
        self.camera = camera
        
class SmartPhone(Phone):
    pass


s = SmartPhone(2000,'Apple',13)
print(s.brand)

# %% [markdown]
# ### Inheriting Private members

# %%
class Phone:
    
    def __init__(self,price,brand,camera):
        print("inside phone constructoe")
        
        self.price = price
        self.__brand = brand
        self.camera = camera
        
class SmartPhone(Phone):
    pass


s = SmartPhone(2000,'Apple',13)
# print(s.__brand) # is not access because this is privet

# %% [markdown]
# ### Polymorphism

# %%
class Phone:
    
    def __init__(self,price,brand,camera):
        
        print("inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print("Buying a phone")
        
class SmartPhone(Phone):
    #its mean method overriding -> Polymorphism
    def buy(self):
        print("Buying a smartphone")
            
s = SmartPhone(2000,"Apple",13)
s.buy()


# Method Overriding -> Polymorphism
# Method Overloding
# Operator Overloading

# %% [markdown]
# ### class parent

# %%
class parent:
    
    def __init__(self,num):
        self.__num = num
    
    def get_num(self):
        return self.__num
    
class Child(parent):
    
    def show(self):
        print("this is in child class")
        
son = Child(100)
print(son.get_num())
son.show()

# %%
class parent:
    
    def __init__(self,num):
        self.__num = num
    
    def get_num(self):
        return self.__num
    
class Child(parent):
    def __init__(self,val,num):
        self.__val = val
           
    def get_val(self):
        # print("this is in child class")
        return self.__val
        
son = Child(100,10)
print("parent Num",son.get_num())

# %%
class A:
    
    def __init__(self):
        
        self.var1 = 200
        
    def disply1(self,var1):
        
        print("class A",self.var1)
class B(A):
    
    def display2(self,var1):
        print("class B:",self.var1)
        
obj = B()
obj.disply1(200)

# %% [markdown]
# ### Super

# %%
class Phone:
    
    def __init__(self,price,brand,camera):
        print("inside phone constructor")
        self.__price  = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print("Buying a phone")

class Smartphone(Phone):
    
    def buy(self):
        
        print("Buyinh a smartphone")
        super().buy()

s=Smartphone(2000,"Apple",13)

s.buy()

# %%
class Phone:
    
    def __init__(self,price,brand,camera):
        print("inside phone constructor")
        self.__price  = price
        self.brand = brand
        self.camera = camera

class Smartphone(Phone):
    def __init__(self,price,brand,camera,os,ram):
        
        super().__init__(price,brand,camera)
        self.os = os
        self.ram = ram
        print("inside smartphone constructor")
        
s = Smartphone(20000,"Apple",12,"Android",2)

print(s.os)
print(s.brand)

# %%
class Parent:
    
    def __init__(self,num):
        self.__num=num
        
    def get_num(self):
        return self.__num
    
class Child(Parent):
    
    def __init__(self,num,val):
        super().__init__(num)
        self.__val=val
    
    def get_val(self):
        return self.__val
    
son = Child(100,200)
print(son.get_num())
print(son.get_val())

# %% [markdown]
# ### on Super

# %%
class Parent:
    
    def __init__(self):
        self.num = 100
        
class Child(Parent):
    
    def __init__(self):
        super().__init__()
        self.var = 200
    
    def show(self):
        print(self.num)
        print(self.var)


son = Child()
son.show()

# %%
class Parent:
    
    def __init__(self):
        self.__num = 100
    
    def show(self):
        
        print("Parent",self.__num)
        
class Child(Parent):
    
    def __init__(self):
        super().__init__()  
        self.__var = 200
    
    def show(self):
        print(self.__var)

dad = Parent()
dad.show()
son = Child()
son.show()

# %% [markdown]
# ### Example Single level inheritance

# %%
class Phone:
    
    def  __init__(self,price,brand,camera):
        
        self.__price  =  price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print("Buying a phone")
        
    def return_phone(self):
        print("Returning a phone")
        
class Smartphone(Phone):
    pass

Smartphone(1000,'Apple','13xp').buy()

# %% [markdown]
# ### Multilevel inheritance

# %%
class Product:
    
    def review(self):
        print("Product customer review")
        
class Phone(Product):
    def __init__(self,price,brand , camera):
        print("inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print("Buying a phone")
        
        
class SmartPhone(Phone):
    pass

s = SmartPhone(2000,'Apple',12)
p = Phone(1000,'Samsung',1)

s.buy()
s.review()
p.review()

# %% [markdown]
# ### Hierarchical inheritance

# %%
class Phone:
    
    def __init__(self,price,brand,camera):
        print('inside phone constructor')
        self.__price = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print("Buying a phone")
        
    def return_phone(self):
        print("Returning a Phon")
        
class SmartPhone(Phone):
    pass

class FeaturePhone(Phone):
    pass

SmartPhone(2000,'Apple',12).buy()

# s.buy()
# s.review()

# %% [markdown]
# ### Multiple Inheritance

# %%
class Phone:
    
    def __init__(self,price,brand,camera):
        print("inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera
        
    def buy(self):
        print("Buying a Phone")
        
class Product:
    
    def review(self):
        print("Customer review")
        
class SmartPhone(Phone,Product):
    pass

s = SmartPhone(2000,'Apple',12)

s.buy()
s.review()

# %%
class A:
    
    def m1(self):
        return 20
    
class B(A):
    
    def m1(self):
        return 30
    
    def m2(self):
        return 40
    
class C(B):
    
    def m2(self):
        return 20
    
    
obj1= A()
obj2 = B()
obj3= C()
print(obj1.m1() + obj3.m1() + obj3.m2())

# %%
class A:
    
    def m1(self):
        return 20
    
class B(A):
    
    def m1(self):
        val = super().m1()+30
        return val
    
class C(B):
    
    def m1(self):
        val = self.m1()+20
        return val

obj3= C()
print(obj1.m1())

# %%
class Geometry:
    
    def area(self,radius):
        return 3.14 * radius * radius
    
    def area(self,l,b):
        return l*b
    
obj = Geometry()
# print(obj.area(4)) # because it is methodoverriding

# %%
class Geometry:
    
    def area(self,a,b=0):
        
        if b==0:
            print("Circul",3.14*a*a)
        else:
            print("Rect",a,b)

obj = Geometry()
obj.area(4)
obj.area(4,5)

# %%
def nest(lst):
    
    if not lst:
        return[[]]
    
    some = nest(lst[:-1])
    return some + [[lst[-1]]] 
lst = [1,2,3,8]
print(nest(lst))

# %% [markdown]
# # Small Project in fatching api

# %%
import requests
class IRCTC:

    def __init__(self):
        
        user_input = input(""" How would you like to proced?
                           1. Enter 1 to check live train status.
                           2. Enter 2 to check PNR
                           3. Enter 3 to check train schould""")
        
        if user_input == "1":
            print("live train status")
            
        elif user_input == "2":
            print("PNR")
        else:
            self.train_schedule()
            
    def train_schedule(self):
        #    train_no =  input("Enter the train num")
           self.fetch_data()
           
    def fetch_data(self):

        url = "https://api.themoviedb.org/3/movie/top_rated"

        headers = {
            "accept": "application/json",
            "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3NjA2MDI5ZDNiNGY3NmNjM2ZlZWE1NTE1OTdlMjBlZCIsInN1YiI6IjY0NmE0OTM4MmJjZjY3MDE1NTgzNmQxOCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.luxXQ8sMCfdp-KmPboYzOl5oo5r_yBjeNYHxI1d9BEE"
            }
        response = requests.get(url, headers=headers)

        data = response.json()
        
        for i in data['results']:
            print(i['original_title'],i["id"])
        # print(response.text)
        
        # for i in data['JSON']:
            # print(i['StationName'])

            # data =requests.get("https://trains.p.rapidapi.com/")
            # data = data.json()
            
obj = IRCTC()
# Out:
# The Godfather 238
# The Shawshank Redemption 278
# Cuando Sea Joven 772071
# The Godfather Part II 240
# दिलवाले दुल्हनिया ले जायेंगे 19404
# Schindler's List 424
# 千と千尋の神隠し 129
# 12 Angry Men 389
# 君の名は。 372058
# 기생충 496243
# The Dark Knight 155
# The Green Mile 497
# Pulp Fiction 680
# Il buono, il brutto, il cattivo 429
# Forrest Gump 13
# 同級生 372754
# The Lord of the Rings: The Return of the King 122
# GoodFellas 769
# Primal: Tales of Savagery 704264
# 七人の侍 346

# %%
# AIzaSyAva4j4iiBrt8AYnVem-jzELo0Nr01hSG4

# %%
import requests

url = "https://api.themoviedb.org/3/movie/top_rated"
url = "https://api.themoviedb.org/3/movie/top_rated"
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI3NjA2MDI5ZDNiNGY3NmNjM2ZlZWE1NTE1OTdlMjBlZCIsInN1YiI6IjY0NmE0OTM4MmJjZjY3MDE1NTgzNmQxOCIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.luxXQ8sMCfdp-KmPboYzOl5oo5r_yBjeNYHxI1d9BEE"
}

response = requests.get(url, headers=headers)

print(response.json())
