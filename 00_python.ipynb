# %% [markdown]
# # What is Print function.
# Answer. print funcation is python function that prints the answer .show the script and perform the multi task.
#
# ## print() is defult funcation  and what work is end kewords

# %%
# print() is defult funcation  and what work is sep kewords 
print("Aziz","basit",sep=" ")
print("Aziz","basit",sep="")
print("Aziz","basit",sep="-")
print("Aziz","basit",sep="/")
print("Aziz","basit",sep="*")
# print() is defult feuncation and works is end kewords
print("Aziz",sep=" ",end="\n")
print("basit")
print("Aziz",end="/")
print("basit")
print( )
# Out:
# Aziz basit
# Azizbasit
# Aziz-basit
# Aziz/basit
# Aziz*basit
# Aziz
# basit
# Aziz/basit
