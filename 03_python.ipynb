# %% [markdown]
# # variable
# 1. variable is contenear in store the data
# 2. variable is a contener in feature use
# ### Type of variable
# #### Dynamic Binding
# 1. one variable multiple datatype  store is dynamin Binding
# 2. python was automatical detect the value
# **Eg**
#  1. a=20
#  2. a="Aziz"
#  3. a=2.0
# #### Static Binding
# 1. one variable store of one datatype is Static Binding
# 2. C,C++,java, is declarationr the data is all time
# **Eg**
#  1. int a=20
#  2  str a="Aziz"
#  3. float a=2.0
#  is provied a error

# %%
# C language
# int a =5

# %%
# python
name = "Abdul Aziz"
print(name)
# Out:
# Abdul Aziz

# %%
name = "Helo words"
print(name)
# Out:
# Helo words

# %%
# no variable declaration

# %%
# Dynamic Typing -->php
# Static typing

# %%
print(name)
# Out:
# Helo words

# %%
# Dynamic Binding

# %%
# Static Binding

# %%
# special stntax
a=5;b=20;c=30
print(a)
print(b)
print(c)
# Out:
# 5
# 20
# 30

# %%
a,b,c = 4,5,6
print(a)
print(b)
print(c)
# Out:
# 4
# 5
# 6

# %%
a = b = c =6
print(a)
print(b)
print(c)
# Out:
# 6
# 6
# 6
