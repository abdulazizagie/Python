# %% [markdown]
# # input
# 1. input is bydefult string
# 2. because string is universal
#
# **Eg**
# 1. 5 was convert to string and pakistan is not convert to string

# %%
first_num = int(input("Enter the fist number"))
second_num = int(input("Enter the second number"))
print(first_num)
print(second_num)
sum = first_num+second_num
print(sum)
# Out:
# 4
# 4
# 8

# %%
# type
type({1,2,3,3})
# Out:
# set

# %% [markdown]
# # implicit
# 1. so this condation compiler as automatical convert
# # Explicit
# 1. so this condation compiler as not automatical convert

# %%
4+5.5
# Out:
# 9.5

# %%
5+6+7j
# Out:
# (11+7j)

# %%
int("5")
# Out:
# 5

# %%
float("4.8")
# Out:
# 4.8

# %%
str(4.7)
# Out:
# '4.7'

# %%
bool(1)
# Out:
# True

# %%
complex(4)
# Out:
# (4+0j)

# %%
list('Hello')
# Out:
# ['H', 'e', 'l', 'l', 'o']

# %%
# int("Abdul")

# %% [markdown]
# type conversion is not perment converation
#
# ### and
#
# typecasting is a perment conversion

# %%
a = 4.5
int(a)
# Out:
# 4

# %%
a
# Out:
# 4.5
