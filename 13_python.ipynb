# %% [markdown]
# # module
# #### what are modules?
# #### A file containing a set of funcation you want to include  in your application.
#
# ### Example
# 1. Math
# 2. Random
# 3. os
# 4. time

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# test_sqlite3: testing with version '2.6.0', sqlite_version '3.40.1'
# c:\Program Files\Python311\Lib\site-packages\_distutils_hack\__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# IPython             asyncio             math                symtable
# __future__          asyncore            matplotlib_inline   sys
# __hello__           atexit              mimetypes           sysconfig
# __phello__          audioop             mmap                tabnanny
# _abc                backcall            mmapfile            tarfile
# _aix_support        base64              mmsystem            telnetlib
# _ast                bdb                 modulefinder        tempfile
# _asyncio            binascii            msilib              test
# _bisect             bisect              msvcrt              textwrap
# ...

# %%
# Math
import math as m

# %%
m.pi
# Out:
# 3.141592653589793

# %%
m.e
# Out:
# 2.718281828459045

# %%
m.factorial(5)
# Out:
# 120

# %%
m.ceil(6.3)
# Out:
# 7

# %%
m.floor(6.9)
# Out:
# 6

# %%
m.sqrt(100)
# Out:
# 10.0

# %%
import random as r

# %%
r.randint(1,100)
# Out:
# 49

# %%
a = [1,2,3,4,5]
r.shuffle(a)
print(a)
# Out:
# [4, 5, 2, 1, 3]

# %%
import time as t

# %%
t.time()
# Out:
# 1681381567.5712771

# %%
t.ctime()
# Out:
# 'Thu Apr 13 15:26:07 2023'

# %%
print("Hello")
t.sleep(5)
print("World")
# Out:
# Hello
# World

# %%
import os
os.getcwd()
# Out:
# 'd:\\project file\\Python'

# %%
os.listdir()
# Out:
# ['.py',
#  '.vscode',
#  '00_python.ipynb',
#  '01_python.ipynb',
#  '02_python.ipynb',
#  '03_python.ipynb',
#  '04_python.ipynb',
#  '05_python.ipynb',
#  '06_python.ipynb',
#  '07_python.ipynb',
#  '08_pyhon.ipynb',
#  '09_python.ipynb',
#  '10_python.ipynb',
#  '11_pythoon.ipynb',
#  '12_python.ipynb',
#  '13_python.ipynb',
#  '14_python.ipynb',
#  '15_python.ipynb',
#  '16_python.ipynb']
