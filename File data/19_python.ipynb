# %% [markdown]
# # Some Theory
#
# Types of daata used for I/O:
#
#    - Text -'1234' as a sequence of unicode chars
#    - Binary-'12345 as a sequence of bytes of its binary equivalent
# ## Hence there are 2 file types to deal with
#
#   - Text file - All progra, file are text files
#   - Binary File - Images,music,video,exe files
#
# ## How File I/O is done in most programming languages
#
#    - open a file
#    - Read/Write data
#    - Close the file
#
# # Writing to file

# %%
# case 1- if the file is not present
f = open('sample','w')
f.write("Hi aziz\n")
f.write("how are you")
f.close()
# since file is closed hence this will not work
# f.write('hello')

# %%
# write multiline strings
f = open('sample1.txt','w')
f.write('Hello world\n')
f.write("aRE YOU GOOD")
f.close()

# %%
# case 2 - if the file is already present
f = open('sample.txt', 'w')
f.write(' salman khan?')
f.close()

# %%
# how exactly open() works?

# %%
# Problem with w mode
# introducing append 
f = open('C:/Users/Hp/project file/Python/sample.txt','a')
f.write('\n i am fine')
f.close()

# %%
# Write lines
# how to save anther file 
L = ['hello\n','ho\n','How are you\n','i am fine\n']

f = open('C:/Users/Hp/project file/Python/File data/sample.txt','w')
f.writelines(L)
f.close()

# %%
# reading from files
# -> using read()
f = open('C:/Users/Hp/project file/Python/sample.txt','r')
s = f.read()
print(s)
f.close()
# Out:
#  salman khan?
#  i am fine

# %%
# reading uto n chars

f = open('C:/Users/Hp/project file/Python/sample.txt','r')
s = f.read(10)
print(s)
f.close()
# Out:
#  salman kh

# %%
# reading( -> to read line by lie
f = open('C:/Users/Hp/project file/Python/sample.txt','r')
print(f.readline(),end='')
print(f.readline())
f.close()
# Out:
#  salman khan?
#  i am fine

# %%
# reading enter usiong readline

f = open('C:/Users/Hp/project file/Python/sample.txt','r')

while True:
    
    data = f.readline()
    
    if  data == '':
       break
    else: 
        print(data,end='')
        
f.close()
# Out:
#  salman khan?
#  i am fine

# %% [markdown]
# # Using contex Manger (With)
#    - it's a good idea to close a file after usage as it will free up the resources
#    - if we dont close it, grabage collector would close it.
#   - with keyword closes the file as soon as the usage ir over

# %%
# with 
# with is automaticaly close  file

with open('C:/Users/Hp/project file/Python/sample.txt','w') as f:
    f.write('Selman bhai')

# %%
# try f.read() now

with open('C:/Users/Hp/project file/Python/sample.txt') as f:
    print(f.read())
# Out:
# Selman bhai

# %%
# moving within a file -> 10 chare than 10 char
with open('C:/Users/Hp/project file/Python/File data/sample.txt') as f:
    print(f.read(10))
    print(f.read(10))
# Out:
# hello
# ho
# H
# ow are you

# %%
# benefit ? -> to load a big file in memory
big_L = ['hello world' for i in range(1000)]

with open('big.txt','w') as f:
    f.writelines(big_L)

# %%
with open('big.txt','r') as f:
    Chunk_size = 10
    
    while len(f.read(Chunk_size)) > 0:
        print(f.read(Chunk_size),end='***')
        f.read(Chunk_size)
# Out:
# dhello wor***orldhello ***o worldhel***ello world***ldhello wo***worldhello***lo worldhe***hello worl***rldhello w*** worldhell***llo worldh***dhello wor***orldhello ***o worldhel***ello world***ldhello wo***worldhello***lo worldhe***hello worl***rldhello w*** worldhell***llo worldh***dhello wor***orldhello ***o worldhel***ello world***ldhello wo***worldhello***lo worldhe***hello worl***rldhello w*** worldhell***llo worldh***dhello wor***orldhello ***o worldhel***ello world***ldhello wo***worldhello***lo worldhe***hello worl***rldhello w*** worldhell***llo worldh***dhello wor***orldhello ***o worldhel***ello world***ldhello wo***worldhello***lo worldhe***hello worl***rldhello w*** worldhell***llo worldh***dhello wor***orldhello ***o worldhel***ello world***ldhello wo***worldhello***lo worldhe***hello worl***rldhello w*** worldhell***llo worldh***dhello wor***orldhello ***o worldhel***ello world***ldhello wo***worldhello***lo worldhe***hello worl***rldhello w*** worldhell***llo worldh
# ...

# %%
# seel and tell funcation

with open("File data/sample.txt",'r') as f:
    print(f.read(10))
    print(f.tell())
    f.seek(0)
    print(f.read(10))
# Out:
# hello
# ho
# H
# 12
# hello
# ho
# H

# %%
# seek during write 
with open('File data/sample.txt','w') as f:
    f.write("hello")
    f.seek(0)
    f.write('Hi')

# %% [markdown]
# # Problem with working in text mode
#    - can't work with binary file like images
#    - not good  for other data type like int/gloat/tuples

# %%
# working with binary file

with open('images.png','r') as f:
    f.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[18], line 4
#       1 # working with binary file
#       3 with open('images.png','r') as f:
# ----> 4     f.read()
#
# File c:\Program Files\Python311\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 240: character maps to <undefined>

# %%
# working with binary file

with open('images.png','rb') as f:
    with open('images_copy.png','wb') as wf:
        wf.write(f.read())

# %%
# working with a big binary file

# %%
# working with other data types

with open('sample.txt','w') as f:
    f.write('5')

# %%
with open('sample.txt','r') as f:
    print(int(f.read()) + 5 )
# Out:
# 10

# %%
# more complex data 
d = {
    'name' : ' nitish',
    'age' : 33,
    'render' : 'male'
}

with open('sample.txt', 'w') as f:
    f.write(str(d))

# %%
with open('sample.txt','r') as f:
    # print(dict(f.read()))
    print(type(f.read()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 2
#       1 with open('sample.txt','r') as f:
# ----> 2     print(dict(f.read()))
#       3     print(type(f.read()))
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %% [markdown]
# # Serialization and Deserialization
#   - serialzation-process of converting python data type to json format
#   - Deserialization-process of converting JSON to python data types
#
# ### What is Json
#
# ![IM](Image.png)

# %%
# seriaization using json module
#  List

import json

L = [1,2,3,4]

with open('demo.json','w') as f:
    json.dump(L,f)

# %%
d = {
    'name' : 'nitish',
    'age' : 33,
    'gender' : 'male'
}

with open('demo.json','w') as f:
    json.dump(d,f,indent=4)

# %%
# deserialization 

import json

with open('demo.json','r') as f:
    print(json.load(f))
    print(type(d))
# Out:
# {'name': 'nitish', 'age': 33, 'gender': 'male'}
# <class 'dict'>

# %%
# serialize and deserialize tuple
import json

t = (1,2,3,4,5)

with open('demo.json','w') as f:
    json.dump(t,f)

# %%
# serial and deserialize a nested dict

d = {
    'student' : 'nitish',
    'marks': [23,32,23,43,34,56]
    
}
with open('demo.json','w') as f:
    json.dump(d,f)

# %% [markdown]
# # serializing and Deserializing cuntom objects

# %%
class Person:
    
    def __init__(self,fname,lname,age,gender):
        
        self.fname = fname
        self.lname = lname
        self.age = age
        self.gender = gender
        
# format to printed in
# -> Nitish Singh age -> 33 age  -> male

# %%
person = Person('Nitish','Singh',33,'male')

# %%
# As a string

import json

def show_object(person):
    if isinstance(person,Person):
        return "{} {} age --> {}".format(person.fname,person.lname,person.age,person.gender)

import json

with open('demo.json','w') as f:
    json.dump(person , f , default=show_object)

# %%
# As a dict

def show_object(person):
    if isinstance(person,Person):
        return {'name':person.fname + ' ' + person.lname,'age':person.age,'gender' : person.gender}
    
with open('demo.json','w') as f:
    json.dump(person ,f ,default=show_object,indent=4)

# %%
# indent arrtribute
# As a dict

# %%
# deserializing

import json

with open('demo.json' , 'r') as f:
    
    d = json.load(f)
    print(d)
    print(type(d))
# Out:
# {'name': 'Nitish Singh', 'age': 33, 'gender': 'male'}
# <class 'dict'>

# %% [markdown]
# # Pickling
#    - Pickling is the process whereby a python object hierarchy is converted into a byte stream , and __unpickling__ is the inverse operation,Whereby a byte strem (from a binary file or bytes or bytes-like object) is converted back into object hierarchy.

# %%
class Person:
    
    def __init__(self,name,age):
        self.name = name
        self.age = age
    
    def display_info(self):
        print('Hi my name is ',self.name,'and I am ',self.age,'years old')

# %%
p = Person('aziz',34)

# %%
#  pickle dump
import pickle

with open('person.pkl','wb') as f:
    pickle.dump(p,f)

# %%
# pickle load
import pickle

with open('person.pkl','rb') as f:
    p = pickle.load(f)
p.display_info()
# Out:
# Hi my name is  aziz and I am  34 years old

# %% [markdown]
# # Pickle Vs Json
#    - Pickle lets the user to store data in binary formate.
#    - Json lets the user store data in a  human readable text format.
