# %% [markdown]
# # Python supports 3 categories of data types:
# 1. Basic Types - (integer.float,complex.boolean and string)
# 2. Container Types - (List.Tuples,Sats and Dictonary)
# 3. User-defined Types-Class

# %%
# integer 
print(4)
# print(le309) is the bigest number of python in integer
# Out:
# 4

# %%
# float
print(4.5)
# print(l.7e308) is the bigest number of python in float
# Out:
# 4.5

# %%
# bollean
print(True)
print(False)
# Out:
# True
# False

# %%
# complex
print(4+5j)
# Out:
# (4+5j)

# %%
# string
print('Kolkate')
print("Kolkate")
print("""kolkate""")
# Out:
# Kolkate
# Kolkate
# kolkate

# %%
# list
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# dictionary
print({"name":"Aziz","Age":30,"gender":"male"})
# Out:
# {'name': 'Aziz', 'Age': 30, 'gender': 'male'}
