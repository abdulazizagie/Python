# %% [markdown]
# ## built-in-funcations in python
# . Are you find the all built-in functions print --help
# show you all built-in functions in python

# %%
# print()
print("Hello words")
# Out:
# Hello words

# %%
# input()
input("enter the number")
# Out:
# '2'

# %%
# type
a = True
type(a)
# Out:
# bool

# %%
# int etc
int(5.4)
# float
# str
# list
# tuple
# Out:
# 5

# %%
# abs mean is absolute modules funcation
abs(-4)
# Out:
# 4

# %%
# pow
pow(2,3) # actually 2 the power 3
# Out:
# 8

# %%
# min/ max
print(min("Aziz"))
print(min([1,2,4,5]))
print(max("Aziz"))
# Out:
# A
# 1
# z

# %%
# round
c = 22/7
round(c,2) # actually works is after the point 16 value is print() because the round funcation is used sum value print
# Out:
# 3.14

# %%
# divmod
divmod(5,2) # the first answer is int division and the second is modules
# Out:
# (2, 1)

# %%
# bin/oct/hex
print(bin(5)) # is convert the bineray
print(oct(5)) # is oact is octal
print(hex(5)) # is hex is hexa
# Out:
# 0b101
# 0o5
# 0x5

# %%
# id 
a = 3 
id(a) # is provied the location of memary
# Out:
# 140730896343912

# %%
# ord
ord('C') #  is provied the askey value
# Out:
# 67

# %%
# len()
len("pakistan")
# Out:
# 8

# %%
# sum()
sum([1,2,3,4,5])
# Out:
# 15

# %%
# help
help("sum")
# Out:
# Help on built-in function sum in module builtins:
#
# sum(iterable, /, start=0)
#     Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
#     When the iterable is empty, return the start value.
#     This function is intended specifically for use with numeric values and may
#     reject non-numeric types.
