# %% [markdown]
# ### Kewords
# 1. Python is a case sensitive programming language
#
# in programing . a kewords is a word that is reserved by a program becaouse the word has a special meaning . keywords can be commands or parameter . Every programming language has a set of keywords that cannot used as variable names

# %%
# python has 33 keywords
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Identifiers
# A Python identifier is name used to identify a variable,funcation  class module or other object.
# ## Rules for setteing Identifier
# 1. can only start with an alphabet or_
# 2. Followed by 0 or more letter, _and digits
# 3. keywords cannot be used as an identifiers

# %%
name = "Abdul Aziz"
print(name)
# Out:
# Abdul Aziz
